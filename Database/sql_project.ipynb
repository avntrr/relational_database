# %% [markdown]
# ## 1. BUAT TABEL CITY

# %%
import pandas as pd
import numpy as np
import random
from faker import Faker

# %%
df_city = pd.read_csv('/Users/avntrr/Documents/Pacmann/data_engineer/sql_project/Database/city - city.csv', delimiter=',')
df_city
# Out:
#     kota_id             nama_kota  latitude   longitude
# 0      3171    Kota Jakarta Pusat -6.186486  106.834091
# 1      3172    Kota Jakarta Utara -6.121435  106.774124
# 2      3173    Kota Jakarta Barat -6.135200  106.813301
# 3      3174  Kota Jakarta Selatan -6.300641  106.814095
# 4      3175    Kota Jakarta Timur -6.264451  106.895859
# 5      3573           Kota Malang -7.981894  112.626503
# 6      3578         Kota Surabaya -7.289166  112.734398
# 7      3471       Kota Yogyakarta -7.797224  110.368797
# 8      3273          Kota Bandung -6.914744  107.609811
# 9      1371           Kota Padang -0.950000  100.353056
# 10     1375      Kota Bukittinggi -0.305556  100.369167
# 11     6471       Kota Balikpapan -1.263539  116.827883
# 12     6472        Kota Samarinda -0.502183  117.153801
# 13     7371         Kota Makassar -5.133333  119.416667
# 14     5171         Kota Denpasar -8.656290  115.222099

# %% [markdown]
# ## 2. BUAT TABEL CAR_PRODUCT

# %%
df_car_product = pd.read_csv('/Users/avntrr/Documents/Pacmann/data_engineer/sql_project/Database/car_product - car_product.csv', delimiter=',')
df_car_product.head()
# Out:
#    product_id   brand         model  body_type  year      price
# 0           1  Toyota  Toyota Yaris  Hatchback  2016  175000000
# 1           2  Toyota  Toyota Yaris  Hatchback  2018  215000000
# 2           3  Toyota  Toyota Yaris  Hatchback  2014  162000000
# 3           4  Toyota  Toyota Yaris  Hatchback  2020  220000000
# 4           5  Toyota  Toyota Yaris  Hatchback  2012  124000000

# %%
# Membuat daftar merek mobil yang ada
brands = df_car_product['brand'].unique().tolist()

# Membuat 200 baris data acak
rows = []
for i in range(450):
    # Memilih merek secara acak dari daftar brand
    random_brand = random.choice(brands)
    
    # Memilih baris secara acak yang memiliki brand yang sama
    random_model = df_car_product[df_car_product['brand']==random_brand]['model'].sample(n=1).iloc[0]
    
    # Memilih tahun secara acak antara 2010 dan 2022
    random_year = random.randint(2010, 2022)
    
    # Memilih harga secara acak antara 80juta dan 450juta
    random_price = random.randint(80000000, 450000000)
    
    # Memilih tipe bodi mobil secara acak
    random_body_type = df_car_product[df_car_product['model']==random_model]['body_type'].sample(n=1).iloc[0]

    new_data = {'product_id':max(df_car_product['product_id'])+1, 'brand':random_brand, 'model':random_model, 'body_type':random_body_type, 'year':random_year, 'price':random_price}

    df_car_product = df_car_product.append(new_data, ignore_index=True)
# Out:
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# ...
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)
# /var/folders/d1/6qk1n6ts36zb0kb689t4gg0r0000gn/T/ipykernel_338/510076401.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_car_product = df_car_product.append(new_data, ignore_index=True)

# %%
df_car_product.head(10)
# Out:
#    product_id   brand         model  body_type  year      price
# 0           1  Toyota  Toyota Yaris  Hatchback  2016  175000000
# 1           2  Toyota  Toyota Yaris  Hatchback  2018  215000000
# 2           3  Toyota  Toyota Yaris  Hatchback  2014  162000000
# 3           4  Toyota  Toyota Yaris  Hatchback  2020  220000000
# 4           5  Toyota  Toyota Yaris  Hatchback  2012  124000000
# 5           6  Toyota   Toyota Agya  Hatchback  2019  114000000
# 6           7  Toyota   Toyota Agya  Hatchback  2014   97000000
# 7           8  Toyota   Toyota Agya  Hatchback  2016  110000000
# 8           9  Toyota   Toyota Agya  Hatchback  2022  155500000
# 9          10  Toyota   Toyota Agya  Hatchback  2017  115500000

# %% [markdown]
# #MENAMBAHKAN DATA DUMMY LAIN BERUPA:
# 1. Tipe transmisi (Manual, Matic)
# 2. Warna mobil (Merah, Kuning, Biru, Hitam, Putih)
# 3. Tanggal posting
# 4. Jarak tempuh
# 5. Opsi bid (Tersedia, Tidak Tersedia)
# 6. kota_id

# %%
kota_id = df_city['kota_id'].unique().tolist()

date_post = pd.date_range(start='2022-01-02', end='2022-12-1', periods=len(df_car_product)).to_list()
random.shuffle(date_post)

transmisi = ['manual', 'matic']
warna = ['merah', 'kuning', 'biru', 'hitam', 'putih']
opsi_bid = ['tersedia', 'tidak_tersedia']


df_car_product['transmisi'] = [random.choice(transmisi) for i in range(len(df_car_product))]
df_car_product['warna'] = [random.choice(warna) for i in range(len(df_car_product))]
df_car_product['opsi_bid'] = [random.choice(opsi_bid) for i in range(len(df_car_product))]
df_car_product['date_post'] = [d.date() for d in date_post]
df_car_product['total_km'] = [random.randint(40000, 100000)for i in range(len(df_car_product))]
df_car_product['kota_id'] = [random.choice(kota_id) for i in range(len(df_car_product))]

# %%
df_car_product.head(10)
# Out:
#    product_id   brand         model  body_type  year      price transmisi  \
# 0           1  Toyota  Toyota Yaris  Hatchback  2016  175000000    manual
# 1           2  Toyota  Toyota Yaris  Hatchback  2018  215000000     matic
# 2           3  Toyota  Toyota Yaris  Hatchback  2014  162000000     matic
# 3           4  Toyota  Toyota Yaris  Hatchback  2020  220000000     matic
# 4           5  Toyota  Toyota Yaris  Hatchback  2012  124000000    manual
# 5           6  Toyota   Toyota Agya  Hatchback  2019  114000000     matic
# 6           7  Toyota   Toyota Agya  Hatchback  2014   97000000     matic
# 7           8  Toyota   Toyota Agya  Hatchback  2016  110000000    manual
# 8           9  Toyota   Toyota Agya  Hatchback  2022  155500000    manual
# 9          10  Toyota   Toyota Agya  Hatchback  2017  115500000    manual
#
#     warna        opsi_bid   date_post  total_km  kota_id
# 0   putih        tersedia  2022-10-20     83223     5171
# 1   putih  tidak_tersedia  2022-08-16     82810     3174
# 2   hitam        tersedia  2022-10-17     50365     3175
# 3   putih        tersedia  2022-09-26     46051     3173
# 4   putih  tidak_tersedia  2022-06-09     65743     7371
# 5   putih        tersedia  2022-04-06     81320     6471
# 6    biru  tidak_tersedia  2022-03-12     90904     3273
# 7  kuning        tersedia  2022-08-31     78458     3172
# 8   merah        tersedia  2022-02-03     42884     3173
# 9   hitam        tersedia  2022-08-03     42728     6472

# %% [markdown]
# ## 3. BUAT TABEL PENJUAL

# %%
df_seller = pd.DataFrame()

fake = Faker('id_ID')
# Membuat data frame buyer dengan kolom-kolom buyer_id, first_name, last_name, email, phone, dan alamat
id_list = range(1, 101)
df_seller = pd.DataFrame({'seller_id': id_list})
df_seller['firstname'] = [fake.first_name() for i in id_list]
df_seller['lastname'] = [fake.last_name() for i in id_list]
df_seller['fullname'] = [f"{df_seller['firstname'][i]} {df_seller['lastname'][i]}" for i in range(len(df_seller))]
df_seller['email'] = [f"{name.lower().replace(' ', '')}@{fake.free_email_domain()}" \
                        for name in df_seller['fullname']]
df_seller['phone'] = [fake.phone_number() for i in range(len(df_seller))]
df_seller['alamat'] = [random.choice(df_city['nama_kota']) for i in range(len(df_seller))]


date_post = pd.date_range(start='2022-01-02', end='2022-12-1', periods=len(df_seller))

df_seller['date_created'] = [d.date() for d in date_post]

# Menampilkan data frame buyer
df_seller.head(10)
# Out:
#    seller_id firstname   lastname           fullname  \
# 0          1    Silvia   Marpaung    Silvia Marpaung
# 1          2   Gambira  Wulandari  Gambira Wulandari
# 2          3     Sidiq    Samosir      Sidiq Samosir
# 3          4      Arta  Budiyanto     Arta Budiyanto
# 4          5   Kuncara  Handayani  Kuncara Handayani
# 5          6    Banara  Maheswara   Banara Maheswara
# 6          7      Emin    Halimah       Emin Halimah
# 7          8      Wira     Wijaya        Wira Wijaya
# 8          9    Shania   Hassanah    Shania Hassanah
# 9         10    Banawa   Palastri    Banawa Palastri
#
#                           email                phone                alamat  \
# 0      silviamarpaung@gmail.com    +62-0801-649-6332    Kota Jakarta Pusat
# 1  gambirawulandari@hotmail.com  +62 (0085) 842-9732      Kota Bukittinggi
# 2        sidiqsamosir@yahoo.com     +62-035-187-4146  Kota Jakarta Selatan
# 3       artabudiyanto@gmail.com     +62-451-667-7075           Kota Malang
# 4    kuncarahandayani@yahoo.com  +62 (0977) 914 1468    Kota Jakarta Pusat
# 5     banaramaheswara@gmail.com    +62 (62) 575-9523      Kota Bukittinggi
# 6         eminhalimah@gmail.com     +62-736-577-5627         Kota Denpasar
# 7          wirawijaya@yahoo.com    +62 (65) 946-7528           Kota Malang
# 8      shaniahassanah@gmail.com      (0712) 384-5415    Kota Jakarta Barat
# 9      banawapalastri@yahoo.com   +62 (190) 003 4412           Kota Malang
#
#   date_created
# 0   2022-01-02
# 1   2022-01-05
# 2   2022-01-08
# 3   2022-01-12
# 4   2022-01-15
# 5   2022-01-18
# 6   2022-01-22
# 7   2022-01-25
# 8   2022-01-28
# 9   2022-02-01

# %%
# Menambahkan kolom "seller_id" pada df_car_product dengan nilai acak dari df_seller
df_car_product['seller_id'] = [random.choice(df_seller['seller_id']) for i in range(len(df_car_product))]

# Mengubah nilai "date_created" pada df_car_product jika lebih besar dari "date_post"
for index, row in df_car_product.iterrows():
    seller_id = row['seller_id']
    date_created = df_seller.loc[df_seller['seller_id'] == seller_id, 'date_created'].values[0]
    if date_created > row['date_post']:
        df_car_product.at[index, 'date_post'] = date_created

df_car_product.head(10)
# Out:
#    product_id   brand         model  body_type  year      price transmisi  \
# 0           1  Toyota  Toyota Yaris  Hatchback  2016  175000000    manual
# 1           2  Toyota  Toyota Yaris  Hatchback  2018  215000000     matic
# 2           3  Toyota  Toyota Yaris  Hatchback  2014  162000000     matic
# 3           4  Toyota  Toyota Yaris  Hatchback  2020  220000000     matic
# 4           5  Toyota  Toyota Yaris  Hatchback  2012  124000000    manual
# 5           6  Toyota   Toyota Agya  Hatchback  2019  114000000     matic
# 6           7  Toyota   Toyota Agya  Hatchback  2014   97000000     matic
# 7           8  Toyota   Toyota Agya  Hatchback  2016  110000000    manual
# 8           9  Toyota   Toyota Agya  Hatchback  2022  155500000    manual
# 9          10  Toyota   Toyota Agya  Hatchback  2017  115500000    manual
#
#     warna        opsi_bid   date_post  total_km  kota_id  seller_id
# 0   putih        tersedia  2022-10-20     83223     5171         63
# 1   putih  tidak_tersedia  2022-09-14     82810     3174         77
# 2   hitam        tersedia  2022-10-17     50365     3175         76
# 3   putih        tersedia  2022-09-26     46051     3173         50
# 4   putih  tidak_tersedia  2022-08-08     65743     7371         66
# 5   putih        tersedia  2022-08-18     81320     6471         69
# 6    biru  tidak_tersedia  2022-09-28     90904     3273         81
# 7  kuning        tersedia  2022-09-07     78458     3172         75
# 8   merah        tersedia  2022-02-03     42884     3173          7
# 9   hitam        tersedia  2022-08-03     42728     6472         37

# %% [markdown]
# ## 4. BUAT TABEL PEMBELI

# %%
df_buyer = pd.DataFrame()

# Membuat data frame buyer dengan kolom-kolom buyer_id, first_name, last_name, email, phone, dan alamat
id_list = range(1, 61)
df_buyer = pd.DataFrame({'buyer_id': id_list})
df_buyer['firstname'] = [fake.first_name() for i in id_list]
df_buyer['lastname'] = [fake.last_name() for i in id_list]
df_buyer['fullname'] = [f"{df_buyer['firstname'][i]} {df_buyer['lastname'][i]}" for i in range(len(df_buyer))]
df_buyer['email'] = [f"{name.lower().replace(' ', '')}@{fake.free_email_domain()}" \
                        for name in df_buyer['fullname']]
df_buyer['phone'] = [fake.phone_number() for i in range(len(df_buyer))]
df_buyer['alamat'] = [random.choice(df_city['nama_kota']) for i in range(len(df_buyer))]

# Menampilkan data frame buyer
df_buyer.head(10)
# Out:
#    buyer_id firstname    lastname            fullname  \
# 0         1     Dimaz     Puspita       Dimaz Puspita
# 1         2    Silvia    Purwanti     Silvia Purwanti
# 2         3   Darmaji   Rahmawati   Darmaji Rahmawati
# 3         4    Uchita    Najmudin     Uchita Najmudin
# 4         5   Shakila  Anggriawan  Shakila Anggriawan
# 5         6     Nurul     Hartati       Nurul Hartati
# 6         7    Rachel    Najmudin     Rachel Najmudin
# 7         8   Pranawa       Usada       Pranawa Usada
# 8         9     Lamar      Namaga        Lamar Namaga
# 9        10     Clara   Mandasari     Clara Mandasari
#
#                          email                phone                alamat
# 0       dimazpuspita@gmail.com         086 020 8989    Kota Jakarta Pusat
# 1   silviapurwanti@hotmail.com   +62 (039) 395-8657      Kota Bukittinggi
# 2   darmajirahmawati@yahoo.com  +62 (0023) 937 0515         Kota Denpasar
# 3     uchitanajmudin@yahoo.com   +62 (091) 097 2390          Kota Bandung
# 4  shakilaanggriawan@yahoo.com   +62 (775) 698 4003         Kota Denpasar
# 5       nurulhartati@yahoo.com     +62-061-553-8023         Kota Denpasar
# 6     rachelnajmudin@yahoo.com      (0921) 192-6387           Kota Padang
# 7       pranawausada@yahoo.com   +62 (011) 936 0536        Kota Samarinda
# 8        lamarnamaga@gmail.com    +62 (52) 406-1833           Kota Malang
# 9     claramandasari@yahoo.com         083 493 8872  Kota Jakarta Selatan

# %% [markdown]
# ## 5. BUAT TABEL BID

# %%
from datetime import date, timedelta

df_bid = pd.DataFrame(columns=['bid_id', 'buyer_id', 'product_id', 'bid_date', 'bid_price', 'bid_status'])

random_buyer_id = df_buyer['buyer_id'].unique().tolist()



n_bid = 1000
for i in range(n_bid):
    bid_id = i + 1
    buyer_id = random.choice(random_buyer_id)
    product_id = df_car_product['product_id'].sample(n=1).iloc[0]
    price = df_car_product[df_car_product['product_id'] == product_id]['price'].iloc[0]
    bid_price = random.uniform(price*0.5, price*0.9)
    bid_status = random.choice(['sent', 'accepted'])

    # Get last bid_date for the current buyer_id and product_id
    last_bid_date = df_bid.loc[(df_bid['buyer_id'] == buyer_id) & (df_bid['product_id'] == product_id), 'bid_date'].max()
    if pd.isna(last_bid_date):
        # If the buyer_id has never bid for the product_id before, then generate a random bid_date
        bid_date = date_post[random.randint(0, len(date_post) - 1)]
    else:
        # Otherwise, generate a random bid_date after the last bid_date
        bid_date = last_bid_date + timedelta(days=random.randint(1, (date_post[-1] - last_bid_date).days))
        # If the random bid_date is after the end of the date_post range, then set the bid_date to the end of the range
        bid_date = min(bid_date, date_post[-1])

    df_bid.loc[i] = [bid_id, buyer_id, product_id, bid_date, bid_price, bid_status]

# %%
df_bid['bid_date'] = df_bid['bid_date'].dt.date

# %%
df_bid = df_bid.reindex(columns=['bid_id', 'buyer_id', 'product_id', 'bid_date', 'bid_price', 'bid_status'])

df_bid.head(10)
# Out:
#    bid_id  buyer_id  product_id    bid_date     bid_price bid_status
# 0       1        11         210  2022-10-11  1.484359e+08       sent
# 1       2        35         350  2022-07-02  2.218888e+08   accepted
# 2       3        52         123  2022-06-29  1.160045e+08   accepted
# 3       4        47          86  2022-02-08  5.307600e+07       sent
# 4       5        33         217  2022-09-01  1.500046e+08       sent
# 5       6        26         296  2022-02-04  2.481059e+08       sent
# 6       7         1          70  2022-06-12  1.395384e+08   accepted
# 7       8        27          54  2022-01-15  2.340564e+08       sent
# 8       9        47         315  2022-09-24  1.030391e+08   accepted
# 9      10        43         393  2022-03-23  1.730010e+08       sent

# %% [markdown]
# ### INSERT DATA DUMMY KE POSTGRESQL

# %%
# from sqlalchemy import create_engine
# engine = create_engine('postgresql://postgres:12310101@localhost:5432/avntrr')

# # df_car_product.to_sql('car_product', engine, if_exists='replace', index=False)
# # df_city.to_sql('city', engine, if_exists='replace', index=False)
# # df_buyer.to_sql('buyer', engine, if_exists='replace', index=False)
# # df_seller.to_sql('seller', engine, if_exists='replace', index=False)
# df_bid.to_sql('bid', engine, if_exists='replace', index=False)
# Out:
# 1000

# %%
output_directory = "/Users/avntrr/Documents/Pacmann/data_engineer/sql_project/Database/"

df_city.to_csv(output_directory + "city.csv", index=False)
df_car_product.to_csv(output_directory + "car_product.csv", index=False)
df_seller.to_csv(output_directory + "seller.csv", index=False)
df_buyer.to_csv(output_directory + "buyer.csv", index=False)
df_bid.to_csv(output_directory + "bid.csv", index=False)

print("All DataFrames have been exported as CSV files.")
# Out:
# All DataFrames have been exported as CSV files.
